# %% [markdown]
# # 0. Load Files

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score, classification_report
import joblib

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
df = pd.read_parquet("/Users/bennyschellinger/Desktop/DataScience/MLE_DataScientest/04_Projekt/MAY24_BDS_INT_Fire_Brigade/data/df_cleaned_for_classification_models.parquet")
df.head()
# Out:
#                 IncidentGroup_Fire  IncidentGroup_Special Service  \
# IncidentNumber
# 235138081                        0                              1
# 2091                             1                              0
# 3091                             1                              0
# 5091                             1                              0
# 6091                             0                              0
#
#                 AggregatedPropertyCategory_Outdoor  \
# IncidentNumber
# 235138081                                        0
# 2091                                             1
# 3091                                             1
# 5091                                             1
# 6091                                             0
#
#                 AggregatedPropertyCategory_Residential  \
# IncidentNumber
# 235138081                                            0
# 2091                                                 0
# 3091                                                 0
# 5091                                                 0
# 6091                                                 1
#
#                 AggregatedPropertyCategory_Vehicle  \
# IncidentNumber
# 235138081                                        1
# 2091                                             0
# 3091                                             0
# 5091                                             0
# 6091                                             0
#
#                 CellEastingNorthing2500_502500-175000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_502500-177500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_502500-180000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_502500-182500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_502500-187500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_502500-190000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_502500-192500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_505000-172500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_505000-175000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_505000-177500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_505000-180000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_505000-182500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_505000-185000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_505000-187500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_505000-190000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_507500-170000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_507500-172500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_507500-175000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_507500-177500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_507500-180000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_507500-182500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                1
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_507500-185000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_507500-187500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_507500-190000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_510000-167500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_510000-170000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_510000-172500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_510000-175000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_510000-177500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_510000-180000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_510000-182500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_510000-185000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_510000-187500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_510000-190000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_512500-167500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_512500-170000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_512500-172500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_512500-175000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_512500-177500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_512500-180000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_512500-182500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_512500-185000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_512500-187500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_512500-190000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_512500-192500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_515000-157500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_515000-160000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_515000-162500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_515000-165000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_515000-167500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_515000-170000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_515000-172500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_515000-175000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_515000-177500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_515000-180000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_515000-182500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_515000-185000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_515000-187500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_515000-190000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_515000-192500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_517500-160000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_517500-162500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_517500-165000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_517500-167500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_517500-170000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_517500-172500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_517500-175000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_517500-177500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_517500-180000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_517500-182500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_517500-185000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_517500-187500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_517500-190000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_517500-192500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_517500-195000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_520000-162500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_520000-165000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_520000-167500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_520000-170000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_520000-172500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_520000-175000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_520000-177500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_520000-180000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_520000-182500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_520000-185000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_520000-187500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_520000-190000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_520000-192500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_520000-195000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_522500-160000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_522500-162500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_522500-165000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_522500-167500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_522500-170000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_522500-172500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_522500-175000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_522500-177500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_522500-180000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_522500-182500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_522500-185000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_522500-187500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_522500-190000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_522500-192500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_522500-195000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_522500-197500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_525000-160000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_525000-162500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_525000-165000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_525000-167500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_525000-170000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_525000-172500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_525000-175000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_525000-177500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_525000-180000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_525000-182500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_525000-185000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# ...
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_547500-182500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_547500-185000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_547500-187500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_547500-190000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_547500-192500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_550000-167500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_550000-170000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_550000-172500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_550000-175000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_550000-177500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_550000-180000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_550000-182500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_550000-185000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_550000-187500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_550000-190000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_550000-192500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_552500-172500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_552500-175000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_552500-177500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_552500-180000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_552500-182500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_552500-185000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_552500-187500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_552500-190000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_552500-192500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_555000-180000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_555000-182500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_555000-185000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_555000-187500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_555000-190000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_555000-192500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_557500-182500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_557500-185000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_557500-187500  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_560000-185000  \
# IncidentNumber
# 235138081                                           0
# 2091                                                0
# 3091                                                0
# 5091                                                0
# 6091                                                0
#
#                 CellEastingNorthing2500_560000-187500  IsBankholiday  \
# IncidentNumber
# 235138081                                           0              1
# 2091                                                0              1
# 3091                                                0              1
# 5091                                                0              1
# 6091                                                0              1
#
#                 IsWeekend  DistanceStationLog  Hour_sin  Hour_cos  \
# IncidentNumber
# 235138081               0            7.207600       0.0       1.0
# 2091                    0            6.454777       0.0       1.0
# 3091                    0            5.940170       0.0       1.0
# 5091                    0            7.031189       0.0       1.0
# 6091                    0            6.281069       0.0       1.0
#
#                 Weekday_sin  Weekday_cos  Month_sin  Month_cos  \
# IncidentNumber
# 235138081          0.433884    -0.900969        0.5   0.866025
# 2091               0.433884    -0.900969        0.5   0.866025
# 3091               0.433884    -0.900969        0.5   0.866025
# 5091               0.433884    -0.900969        0.5   0.866025
# 6091               0.433884    -0.900969        0.5   0.866025
#
#                 ResponseTimeBinary
# IncidentNumber
# 235138081                        1
# 2091                             1
# 3091                             1
# 5091                             1
# 6091                             1

# %%
df.columns
# Out:
# Index(['IncidentGroup_Fire', 'IncidentGroup_Special Service',
#        'AggregatedPropertyCategory_Outdoor',
#        'AggregatedPropertyCategory_Residential',
#        'AggregatedPropertyCategory_Vehicle',
#        'CellEastingNorthing2500_502500-175000',
#        'CellEastingNorthing2500_502500-177500',
#        'CellEastingNorthing2500_502500-180000',
#        'CellEastingNorthing2500_502500-182500',
#        'CellEastingNorthing2500_502500-187500',
#        ...
#        'IsBankholiday', 'IsWeekend', 'DistanceStationLog', 'Hour_sin',
#        'Hour_cos', 'Weekday_sin', 'Weekday_cos', 'Month_sin', 'Month_cos',
#        'ResponseTimeBinary'],
#       dtype='object', length=320)

# %% [markdown]
# # 1. Baseline Model

# %% [markdown]
# ## 1.1 Model Training & Evaluation (Baseline)

# %%
X = df.drop("ResponseTimeBinary", axis = 1)
y = df["ResponseTimeBinary"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 666)

# %% [markdown]
# ### Decision Tree

# %%
decision_tree = DecisionTreeClassifier(random_state=666)
decision_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=666)

# %%
# Save the best model
joblib.dump(decision_tree, 'best_dt.pkl')

# To load the model later
#decision_tree = joblib.load('best_dt.pkl')
# Out:
# ['best_dt.pkl']

# %%
y_train_pred_dt = decision_tree.predict(X_train)
y_test_pred_dt = decision_tree.predict(X_test)
y_test_pred_prob_dt = decision_tree.predict_proba(X_test)

# %% [markdown]
# ### Random Forest

# %%
random_forest = RandomForestClassifier(random_state=666)
random_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=666)

# %%
# Save the best model
joblib.dump(random_forest, 'best_rf.pkl')

# To load the model later
#random_forest = joblib.load('best_rf.pkl')
# Out:
# ['best_rf.pkl']

# %%
y_train_pred_rf = random_forest.predict(X_train)
y_test_pred_rf = random_forest.predict(X_test)
y_test_pred_prob_rf = random_forest.predict_proba(X_test)

# %% [markdown]
# ## 1.2 Model Evaluation (Baseline)

# %%
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix, balanced_accuracy_score

def evaluate_model(y_true, y_pred, y_proba = None):
    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    print('Confusion Matrix:\n', cm)
    
    # Accuracy
    accuracy = accuracy_score(y_true, y_pred)
    print(f'Accuracy: {accuracy:.4f}')
    
    # Precision, Recall, F1-Score
    precision = precision_score(y_true, y_pred, average='macro')
    recall = recall_score(y_true, y_pred, average='macro')
    f1 = f1_score(y_true, y_pred, average='macro')
    
    print('Classification Report:\n', classification_report(y_true, y_pred, target_names=['Not Reached (>6 min)', 'Reached (<=6 min)']))
    
    # ROC AUC Score
    if y_proba is not None:
        roc_auc = roc_auc_score(y_true, y_proba[:, 1])
        print(f'ROC AUC Score: {roc_auc:.4f}')
    else:
        roc_auc = None
    
    # Balanced Accuracy
    balanced_acc = balanced_accuracy_score(y_true, y_pred)
    print(f'Balanced Accuracy: {balanced_acc:.4f}')
    
    return accuracy, precision, recall, f1, roc_auc, balanced_acc

# %% [markdown]
# ### Decision Tree

# %% [markdown]
# #### Evaluation Decision Tree (Training Data)

# %%
print("Decision Tree - Training Data")
evaluate_model(y_train, y_train_pred_dt)
# Out:
# Decision Tree - Training Data
# Confusion Matrix:
#  [[361254    200]
#  [  3804 864905]]
# Accuracy: 0.9967
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.99      1.00      0.99    361454
#    Reached (<=6 min)       1.00      1.00      1.00    868709
#
#             accuracy                           1.00   1230163
#            macro avg       0.99      1.00      1.00   1230163
#         weighted avg       1.00      1.00      1.00   1230163
#
# Balanced Accuracy: 0.9975
# (0.9967451467813615,
#  0.9946742761022092,
#  0.9975338837750455,
#  0.9960896878101088,
#  None,
#  0.9975338837750455)

# %% [markdown]
# #### Evaluation Decision Tree (Test Data)

# %%
print("\nDecision Tree - Test Data")
dt_test_acc, dt_test_prec, dt_test_recall, dt_test_f1, dt_test_roc, dt_test_balacc = evaluate_model(y_test, y_test_pred_dt, y_test_pred_prob_dt)
# Out:
# Decision Tree - Test Data
# Confusion Matrix:
#  [[ 39121  51122]
#  [ 49444 167854]]
# Accuracy: 0.6730
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.44      0.43      0.44     90243
#    Reached (<=6 min)       0.77      0.77      0.77    217298
#
#             accuracy                           0.67    307541
#            macro avg       0.60      0.60      0.60    307541
#         weighted avg       0.67      0.67      0.67    307541
#
# ROC AUC Score: 0.6034
# Balanced Accuracy: 0.6030

# %% [markdown]
# ### Random Forest

# %% [markdown]
# #### Evaluation Random Forest (Training Data)

# %%
print("\nRandom Forest - Training Data")
evaluate_model(y_train, y_train_pred_rf)
# Out:
# Random Forest - Training Data
# Confusion Matrix:
#  [[358410   3044]
#  [   989 867720]]
# Accuracy: 0.9967
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       1.00      0.99      0.99    361454
#    Reached (<=6 min)       1.00      1.00      1.00    868709
#
#             accuracy                           1.00   1230163
#            macro avg       1.00      1.00      1.00   1230163
#         weighted avg       1.00      1.00      1.00   1230163
#
# Balanced Accuracy: 0.9952
# (0.9967215726696381,
#  0.9968762015283812,
#  0.9952199935604599,
#  0.9960433605192636,
#  None,
#  0.9952199935604599)

# %% [markdown]
# #### Evaluation Random Forest (Test Data)

# %%
print("\nRandom Forest - Test Data")
rf_test_acc, rf_test_prec, rf_test_recall, rf_test_f1, rf_test_roc, rf_test_balacc = evaluate_model(y_test, y_test_pred_rf, y_test_pred_prob_rf)
# Out:
# Random Forest - Test Data
# Confusion Matrix:
#  [[ 34753  55490]
#  [ 23513 193785]]
# Accuracy: 0.7431
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.60      0.39      0.47     90243
#    Reached (<=6 min)       0.78      0.89      0.83    217298
#
#             accuracy                           0.74    307541
#            macro avg       0.69      0.64      0.65    307541
#         weighted avg       0.72      0.74      0.72    307541
#
# ROC AUC Score: 0.7242
# Balanced Accuracy: 0.6384

# %% [markdown]
# ## 1.3 Evaluation Visualization (Baseline)

# %%
models = ['Logistic Regression', 'SVC', 'Decision Tree', 'KNN', 'Random Forest', 'XGBoost']

test_accuracy = [0.75, 0, 0.67, 0, 0.74, 0.760663]
test_precision = [0.73, 0, 0.67, 0, 0.72, 0.746485]
test_recall = [0.75, 0, 0.67, 0, 0.74, 0.760663]
test_f1score = [0.71, 0, 0.67, 0, 0.72, 0.734577]

test_rocauc = [0.6140058862580664, 0, 0.6033859641359862, 0, 0.638807562492847, 0]

colors = sns.color_palette("husl", 4)

fig, axs = plt.subplots(3, 2, figsize=(14, 10))

axs[0, 0].barh(models, test_accuracy, color=colors, edgecolor='grey')
axs[0, 0].set_title('Test Accuracy')
axs[0, 0].set_xlabel('Accuracy Score')
axs[0, 0].grid(True)

axs[0, 1].barh(models, test_precision, color=colors, edgecolor='grey')
axs[0, 1].set_title('Test Precision (Weighted)')
axs[0, 1].set_xlabel('Precision Score')
axs[0, 1].grid(True)

axs[1, 0].barh(models, test_recall, color=colors, edgecolor='grey')
axs[1, 0].set_title('Test Recall (Weighted)')
axs[1, 0].set_xlabel('Recall Score')
axs[1, 0].grid(True)

axs[1, 1].barh(models, test_f1score, color=colors, edgecolor='grey')
axs[1, 1].set_title('F1-Score (Weighted)')
axs[1, 1].set_xlabel('F1-Score')
axs[1, 1].grid(True)

axs[2, 0].barh(models, test_rocauc, color=colors, edgecolor='grey')
axs[2, 0].set_title('ROC AUC Score')
axs[2, 0].set_xlabel('ROC AUC Score')
axs[2, 0].grid(True)

axs[2, 0].axvline(x=0.5, color='b', linestyle='--', label='Random Model (0.5)')

plt.tight_layout()
plt.suptitle('Evaluation Metrics for Logistic Regression, SVC, KNN, Decision Tree, RF, & XGBoost', y=1.02, fontsize=16)
plt.savefig("/Users/bennyschellinger/Desktop/DataScience/MLE_DataScientest/04_Projekt/MAY24_BDS_INT_Fire_Brigade/img/eval_baseline_clf_models.png")
plt.show()

# %% [markdown]
# # 2. Undersampling Technique

# %%
from imblearn.under_sampling import RandomUnderSampler,  ClusterCentroids

UndSam = RandomUnderSampler(random_state=666)
X_undsam, y_undsam = UndSam.fit_resample(X_train, y_train)
print('Sample classes undersampled :', dict(pd.Series(y_undsam).value_counts()))
# Out:
# Sample classes undersampled : {0: 361454, 1: 361454}

# %% [markdown]
# ## 2.1 Model Training (Undersampled)

# %% [markdown]
# ### Decision Tree (Undersampled)

# %%
decision_tree_undsam = DecisionTreeClassifier(random_state=666)
decision_tree_undsam.fit(X_undsam, y_undsam)
# Out:
# DecisionTreeClassifier(random_state=666)

# %%
# Save the best model
joblib.dump(decision_tree_undsam, 'best_dt_ru.pkl')

# To load the model later
#decision_tree_undsam = joblib.load('best_dt_ru.pkl')
# Out:
# ['best_dt_ru.pkl']

# %%
y_train_pred_dt_undsam = decision_tree_undsam.predict(X_undsam)
y_test_pred_dt_undsam = decision_tree_undsam.predict(X_test)
y_test_pred_prob_dt_undsam = decision_tree_undsam.predict_proba(X_test)

# %% [markdown]
# ### Random Forest (Undersampled)

# %%
random_forest_undsam = RandomForestClassifier(random_state=666)
random_forest_undsam.fit(X_undsam, y_undsam)
# Out:
# RandomForestClassifier(random_state=666)

# %%
# Save the best model
joblib.dump(random_forest_undsam, 'best_rf_ru.pkl')

# To load the model later
#random_forest_undsam = joblib.load('best_rf_ru.pkl')
# Out:
# ['best_rf_ru.pkl']

# %%
y_train_pred_rf_undsam = random_forest_undsam.predict(X_undsam)
y_test_pred_rf_undsam = random_forest_undsam.predict(X_test)
y_test_pred_prob_rf_undsam = random_forest_undsam.predict_proba(X_test)

# %% [markdown]
# ## 2.2 Model Evaluation (Undersampled)

# %% [markdown]
# ### Decision Tree (Undersampled)

# %% [markdown]
# #### Evaluation Decision Tree (Training Data, Undersampled)

# %%
print("Decision Tree - Training Data (Undersampled)")
evaluate_model(y_undsam, y_train_pred_dt_undsam)
# Out:
# Decision Tree - Training Data (Undersampled)
# Confusion Matrix:
#  [[361411     43]
#  [  1637 359817]]
# Accuracy: 0.9977
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       1.00      1.00      1.00    361454
#    Reached (<=6 min)       1.00      1.00      1.00    361454
#
#             accuracy                           1.00    722908
#            macro avg       1.00      1.00      1.00    722908
#         weighted avg       1.00      1.00      1.00    722908
#
# Balanced Accuracy: 0.9977
# (0.9976760528310656,
#  0.9976857317255141,
#  0.9976760528310656,
#  0.9976760415320935,
#  None,
#  0.9976760528310656)

# %% [markdown]
# #### Evaluation Decision Tree (Test Data, Undersampled)

# %%
print("Decision Tree - Test Data (Undersampled)")
dt_test_acc_ru, dt_test_prec_ru, dt_test_recall_ru, dt_test_f1_ru, dt_test_roc_ru, dt_test_balacc_ru = evaluate_model(y_test, y_test_pred_dt_undsam, y_test_pred_prob_dt_undsam)
# Out:
# Decision Tree - Test Data (Undersampled)
# Confusion Matrix:
#  [[ 54750  35493]
#  [ 84002 133296]]
# Accuracy: 0.6115
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.39      0.61      0.48     90243
#    Reached (<=6 min)       0.79      0.61      0.69    217298
#
#             accuracy                           0.61    307541
#            macro avg       0.59      0.61      0.58    307541
#         weighted avg       0.67      0.61      0.63    307541
#
# ROC AUC Score: 0.6104
# Balanced Accuracy: 0.6101

# %% [markdown]
# ### Random Forest (Undersampled)

# %% [markdown]
# #### Evaluation Random Forest (Training Data, Undersampled)

# %%
print("\nRandom Forest - Training Data (Undersampled)")
evaluate_model(y_undsam, y_train_pred_rf_undsam)
# Out:
# Random Forest - Training Data (Undersampled)
# Confusion Matrix:
#  [[360493    961]
#  [   725 360729]]
# Accuracy: 0.9977
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       1.00      1.00      1.00    361454
#    Reached (<=6 min)       1.00      1.00      1.00    361454
#
#             accuracy                           1.00    722908
#            macro avg       1.00      1.00      1.00    722908
#         weighted avg       1.00      1.00      1.00    722908
#
# Balanced Accuracy: 0.9977
# (0.997667753019748,
#  0.9976679651768732,
#  0.997667753019748,
#  0.9976677527711872,
#  None,
#  0.997667753019748)

# %% [markdown]
# #### Evaluation Random Forest (Test Data, Undersampled)

# %%
print("\nRandom Forest - Test Data (Undersampled)")
rf_test_acc_ru, rf_test_prec_ru, rf_test_recall_ru, rf_test_f1_ru, rf_test_roc_ru, rf_test_balacc_ru = evaluate_model(y_test, y_test_pred_rf_undsam, y_test_pred_prob_rf_undsam)
# Out:
# Random Forest - Test Data (Undersampled)
# Confusion Matrix:
#  [[ 58666  31577]
#  [ 68834 148464]]
# Accuracy: 0.6735
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.46      0.65      0.54     90243
#    Reached (<=6 min)       0.82      0.68      0.75    217298
#
#             accuracy                           0.67    307541
#            macro avg       0.64      0.67      0.64    307541
#         weighted avg       0.72      0.67      0.69    307541
#
# ROC AUC Score: 0.7277
# Balanced Accuracy: 0.6667

# %% [markdown]
# # 3. PCA + Undersampling

# %% [markdown]
# ## 3.1 Finding Best Principal Components

# %%
from sklearn.decomposition import PCA

pca = PCA()
X_pca = pca.fit_transform(X)

# %%
print(pca.explained_variance_)

plt.plot(range(0,len(pca.explained_variance_)), pca.explained_variance_)
plt.xlabel('Factor number')
plt.ylabel('Eigenvalues');
# Out:
# [6.54343175e-01 5.32203300e-01 5.14806503e-01 4.99943112e-01
#  4.94973216e-01 4.68662112e-01 4.10316762e-01 3.39185563e-01
#  2.02460411e-01 1.32471758e-01 8.02194373e-02 5.61907431e-02
#  3.66088534e-02 3.09488398e-02 2.35764774e-02 1.98372054e-02
#  1.94383179e-02 1.76447192e-02 1.69618682e-02 1.64500815e-02
#  1.58425773e-02 1.46603844e-02 1.42345540e-02 1.35775544e-02
#  1.32694346e-02 1.29845808e-02 1.26124480e-02 1.24052394e-02
#  1.22416831e-02 1.20193491e-02 1.16364237e-02 1.11694136e-02
#  1.09158207e-02 1.05987744e-02 9.98372087e-03 8.61115142e-03
#  8.56080275e-03 8.48274970e-03 8.36406406e-03 8.28231912e-03
#  8.16525216e-03 8.03769044e-03 7.90005631e-03 7.73628252e-03
#  7.59606412e-03 7.45665415e-03 7.33549350e-03 7.20886705e-03
#  7.01339151e-03 6.90470752e-03 6.76307645e-03 6.71921761e-03
#  6.58420778e-03 6.45850090e-03 6.34080042e-03 6.26672350e-03
#  6.18509683e-03 6.09276247e-03 6.01998382e-03 5.92318910e-03
#  5.83856578e-03 5.75297354e-03 5.73304030e-03 5.64229880e-03
#  5.59008100e-03 5.49949313e-03 5.45773597e-03 5.42131639e-03
#  5.37735776e-03 5.35955588e-03 5.27062643e-03 5.19919085e-03
#  5.17149811e-03 5.07428732e-03 4.96497891e-03 4.89806072e-03
#  4.86453601e-03 4.84979441e-03 4.78432040e-03 4.69482568e-03
#  4.61010782e-03 4.59805508e-03 4.53609905e-03 4.50551254e-03
#  4.36548478e-03 4.30509495e-03 4.17290940e-03 4.09310451e-03
#  4.04087591e-03 4.00993605e-03 3.90097457e-03 3.79987816e-03
#  3.64664825e-03 3.62074332e-03 3.60629733e-03 3.59265668e-03
#  3.57507517e-03 3.54163606e-03 3.52574442e-03 3.49270640e-03
#  3.46063080e-03 3.42378174e-03 3.40777493e-03 3.37463267e-03
#  3.37411987e-03 3.36631580e-03 3.34922309e-03 3.32355005e-03
#  3.30715695e-03 3.29501368e-03 3.27915809e-03 3.26946161e-03
#  3.24616940e-03 3.21424776e-03 3.19238871e-03 3.18515859e-03
#  3.13761935e-03 3.11101291e-03 3.07103685e-03 3.05949652e-03
#  3.04691447e-03 3.02324651e-03 3.00510344e-03 2.98981200e-03
#  2.96944490e-03 2.93800925e-03 2.93409434e-03 2.92514778e-03
#  2.91375160e-03 2.90624859e-03 2.89334087e-03 2.88211898e-03
#  2.86731451e-03 2.84719910e-03 2.83026667e-03 2.82416163e-03
#  2.81369909e-03 2.79216785e-03 2.76859791e-03 2.75038155e-03
#  2.71743835e-03 2.70575644e-03 2.67791320e-03 2.66254026e-03
#  2.63490305e-03 2.60377902e-03 2.57767510e-03 2.56087896e-03
#  2.54621028e-03 2.53258147e-03 2.49692491e-03 2.47721529e-03
#  2.44467379e-03 2.43971872e-03 2.42440456e-03 2.40003637e-03
#  2.39012773e-03 2.35929275e-03 2.31674330e-03 2.31336157e-03
#  2.29452502e-03 2.28444936e-03 2.27980859e-03 2.22850951e-03
#  2.20671841e-03 2.19677570e-03 2.17055389e-03 2.16054510e-03
#  2.15070802e-03 2.14055275e-03 2.13457896e-03 2.11677580e-03
#  2.08357420e-03 1.98560699e-03 1.96511249e-03 1.95240204e-03
#  1.95102164e-03 1.93972037e-03 1.91581683e-03 1.89740815e-03
#  1.89398743e-03 1.88558888e-03 1.88250941e-03 1.88212405e-03
#  1.86907459e-03 1.81176860e-03 1.78615529e-03 1.75720426e-03
#  1.74137207e-03 1.72352539e-03 1.69675559e-03 1.69146688e-03
#  1.66600037e-03 1.64998060e-03 1.63330492e-03 1.58622198e-03
#  1.53149447e-03 1.51906743e-03 1.50548135e-03 1.50129619e-03
#  1.46710137e-03 1.39101306e-03 1.34590541e-03 1.29301131e-03
#  1.27446433e-03 1.25048334e-03 1.22649961e-03 1.20577935e-03
#  1.19412493e-03 1.17207628e-03 1.10941886e-03 1.08730774e-03
#  1.07771086e-03 1.06878233e-03 1.04642722e-03 1.02246310e-03
#  1.01900446e-03 1.01298172e-03 1.00685801e-03 9.97330782e-04
#  9.88278215e-04 9.31025753e-04 9.24828042e-04 9.11904374e-04
#  9.06799962e-04 8.38019218e-04 8.21298195e-04 8.14789680e-04
#  7.96347068e-04 7.74243714e-04 7.64736941e-04 7.61522653e-04
#  7.54129040e-04 7.36337314e-04 7.24911551e-04 7.18862619e-04
#  7.08552371e-04 6.96483173e-04 6.89606648e-04 6.86558318e-04
#  6.54886930e-04 6.49397762e-04 6.26450846e-04 5.92643450e-04
#  5.58324313e-04 5.43857013e-04 5.34776167e-04 5.28389531e-04
#  5.20576481e-04 5.12462075e-04 5.06901553e-04 4.96972419e-04
#  4.65046700e-04 4.15701115e-04 3.68048915e-04 3.63590050e-04
#  3.49555266e-04 3.15755070e-04 2.63402009e-04 2.59410519e-04
#  2.58113793e-04 2.53622710e-04 2.43754840e-04 2.33555721e-04
#  2.18009475e-04 2.07484570e-04 2.02856846e-04 1.95506758e-04
#  1.85202072e-04 1.76179731e-04 1.74625015e-04 1.66922741e-04
#  1.52682752e-04 1.50527556e-04 1.41539861e-04 1.35679981e-04
#  1.32376073e-04 1.20711979e-04 1.18681544e-04 1.10974460e-04
#  1.08913335e-04 1.07542064e-04 1.00446111e-04 9.32974084e-05
#  9.12700751e-05 7.56435792e-05 7.23650220e-05 4.70155213e-05
#  4.56527863e-05 4.30757225e-05 4.17795536e-05 4.11598574e-05
#  4.09678258e-05 3.06775667e-05 2.87973362e-05 2.86109752e-05
#  2.67430801e-05 2.28355864e-05 2.08762879e-05 1.63114987e-05
#  1.04430859e-05 9.16661241e-06 9.10437816e-06 7.83007005e-06
#  7.17675737e-06 5.87281613e-06 5.21981590e-06 3.91570277e-06
#  3.27442670e-06 3.25149745e-06 2.64379076e-06 2.60127190e-06
#  2.60126502e-06 2.60124241e-06 2.60120745e-06 1.95706169e-06
#  6.54905378e-07 6.50311734e-07 5.10926215e-08]

# %%
print(pca.explained_variance_ratio_)

plt.figure()
plt.xlim(0,len(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Explained variance ratio')
plt.axhline(y = 0.85, color = 'r', linestyle = '--')
plt.plot(pca.explained_variance_ratio_.cumsum());
# Out:
# [1.20620767e-01 9.81056615e-02 9.48987587e-02 9.21588605e-02
#  9.12427164e-02 8.63925618e-02 7.56372562e-02 6.25250239e-02
#  3.73212879e-02 2.44196709e-02 1.47875463e-02 1.03581282e-02
#  6.74842823e-03 5.70506872e-03 4.34605707e-03 3.65676454e-03
#  3.58323414e-03 3.25260450e-03 3.12672864e-03 3.03238655e-03
#  2.92040001e-03 2.70247611e-03 2.62397909e-03 2.50286864e-03
#  2.44607025e-03 2.39356068e-03 2.32496219e-03 2.28676563e-03
#  2.25661588e-03 2.21563113e-03 2.14504316e-03 2.05895513e-03
#  2.01220813e-03 1.95376424e-03 1.84038607e-03 1.58736841e-03
#  1.57808720e-03 1.56369900e-03 1.54182065e-03 1.52675189e-03
#  1.50517192e-03 1.48165736e-03 1.45628606e-03 1.42609622e-03
#  1.40024854e-03 1.37454989e-03 1.35221529e-03 1.32887314e-03
#  1.29283943e-03 1.27280477e-03 1.24669668e-03 1.23861180e-03
#  1.21372427e-03 1.19055162e-03 1.16885487e-03 1.15519963e-03
#  1.14015267e-03 1.12313188e-03 1.10971596e-03 1.09187294e-03
#  1.07627359e-03 1.06049563e-03 1.05682116e-03 1.04009399e-03
#  1.03046823e-03 1.01376938e-03 1.00607192e-03 9.99358385e-04
#  9.91255109e-04 9.87973533e-04 9.71580394e-04 9.58412053e-04
#  9.53307210e-04 9.35387500e-04 9.15237730e-04 9.02902118e-04
#  8.96722216e-04 8.94004769e-04 8.81935376e-04 8.65438036e-04
#  8.49821256e-04 8.47599470e-04 8.36178576e-04 8.30540299e-04
#  8.04727764e-04 7.93595583e-04 7.69228671e-04 7.54517540e-04
#  7.44889789e-04 7.39186377e-04 7.19100559e-04 7.00464579e-04
#  6.72218378e-04 6.67443095e-04 6.64780142e-04 6.62265642e-04
#  6.59024689e-04 6.52860567e-04 6.49931124e-04 6.43840938e-04
#  6.37928163e-04 6.31135456e-04 6.28184780e-04 6.22075380e-04
#  6.21980851e-04 6.20542259e-04 6.17391411e-04 6.12658877e-04
#  6.09636995e-04 6.07398520e-04 6.04475720e-04 6.02688285e-04
#  5.98394629e-04 5.92510236e-04 5.88480767e-04 5.87147975e-04
#  5.78384654e-04 5.73480059e-04 5.66110922e-04 5.63983594e-04
#  5.61664235e-04 5.57301314e-04 5.53956845e-04 5.51138041e-04
#  5.47383595e-04 5.41588788e-04 5.40867120e-04 5.39217922e-04
#  5.37117165e-04 5.35734071e-04 5.33354678e-04 5.31286050e-04
#  5.28557013e-04 5.24848964e-04 5.21727662e-04 5.20602267e-04
#  5.18673617e-04 5.14704577e-04 5.10359724e-04 5.07001745e-04
#  5.00929038e-04 4.98775609e-04 4.93643022e-04 4.90809195e-04
#  4.85714587e-04 4.79977225e-04 4.75165263e-04 4.72069083e-04
#  4.69365079e-04 4.66852762e-04 4.60279879e-04 4.56646632e-04
#  4.50647974e-04 4.49734563e-04 4.46911571e-04 4.42419571e-04
#  4.40593025e-04 4.34908946e-04 4.27065435e-04 4.26442051e-04
#  4.22969746e-04 4.21112412e-04 4.20256939e-04 4.10800534e-04
#  4.06783591e-04 4.04950764e-04 4.00117070e-04 3.98272063e-04
#  3.96458709e-04 3.94586699e-04 3.93485499e-04 3.90203688e-04
#  3.84083347e-04 3.66024201e-04 3.62246271e-04 3.59903243e-04
#  3.59648782e-04 3.57565520e-04 3.53159172e-04 3.49765742e-04
#  3.49135170e-04 3.47586992e-04 3.47019327e-04 3.46948291e-04
#  3.44542769e-04 3.33979058e-04 3.29257534e-04 3.23920738e-04
#  3.21002254e-04 3.17712420e-04 3.12777710e-04 3.11802797e-04
#  3.07108332e-04 3.04155269e-04 3.01081296e-04 2.92402089e-04
#  2.82313691e-04 2.80022906e-04 2.77518467e-04 2.76746980e-04
#  2.70443550e-04 2.56417531e-04 2.48102445e-04 2.38352017e-04
#  2.34933090e-04 2.30512467e-04 2.26091337e-04 2.22271791e-04
#  2.20123430e-04 2.16059012e-04 2.04508825e-04 2.00432889e-04
#  1.98663813e-04 1.97017939e-04 1.92897027e-04 1.88479513e-04
#  1.87841952e-04 1.86731727e-04 1.85602891e-04 1.83846654e-04
#  1.82177916e-04 1.71624072e-04 1.70481594e-04 1.68099262e-04
#  1.67158321e-04 1.54479368e-04 1.51397037e-04 1.50197266e-04
#  1.46797579e-04 1.42723075e-04 1.40970609e-04 1.40378092e-04
#  1.39015163e-04 1.35735459e-04 1.33629249e-04 1.32514197e-04
#  1.30613619e-04 1.28388799e-04 1.27121189e-04 1.26559264e-04
#  1.20721002e-04 1.19709135e-04 1.15479131e-04 1.09247120e-04
#  1.02920775e-04 1.00253892e-04 9.85799404e-05 9.74026363e-05
#  9.59623889e-05 9.44665899e-05 9.34415705e-05 9.16112468e-05
#  8.57261014e-05 7.66298008e-05 6.78456565e-05 6.70237150e-05
#  6.44365614e-05 5.82058774e-05 4.85551824e-05 4.78193964e-05
#  4.75803597e-05 4.67524792e-05 4.49334489e-05 4.30533566e-05
#  4.01875820e-05 3.82474347e-05 3.73943661e-05 3.60394604e-05
#  3.41399082e-05 3.24767416e-05 3.21901472e-05 3.07703202e-05
#  2.81453391e-05 2.77480531e-05 2.60912732e-05 2.50110706e-05
#  2.44020324e-05 2.22518886e-05 2.18776008e-05 2.04568870e-05
#  2.00769419e-05 1.98241637e-05 1.85161049e-05 1.71983225e-05
#  1.68246065e-05 1.39440386e-05 1.33396737e-05 8.66677982e-06
#  8.41557503e-06 7.94052245e-06 7.70158836e-06 7.58735438e-06
#  7.55195552e-06 5.65506259e-06 5.30846335e-06 5.27410981e-06
#  4.92978446e-06 4.20948218e-06 3.84830766e-06 3.00684038e-06
#  1.92506481e-06 1.68976136e-06 1.67828918e-06 1.44338489e-06
#  1.32295408e-06 1.08258726e-06 9.62214047e-07 7.21815537e-07
#  6.03603542e-07 5.99376794e-07 4.87352937e-07 4.79515065e-07
#  4.79513798e-07 4.79509630e-07 4.79503186e-07 3.60762196e-07
#  1.20724402e-07 1.19877616e-07 9.41834714e-09]

# %%
# Pie chart of the distribution of the explained variance ratio by each axis.
L1 = list(pca.explained_variance_ratio_[0:10]) # first 6 main principal components
L1.append(sum(pca.explained_variance_ratio_[10:X_pca.shape[1]])) # "Others"


plt.pie(L1, labels=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PCA7', 'PCA8', 'PCA9', 'PCA10', 'Others'], autopct='%1.3f%%');

# %%
print("Explained Variance for 10 Components:",pca.explained_variance_ratio_[0:10].sum())
print("Explained Variance for 20 Components:",pca.explained_variance_ratio_[0:20].sum())
print("Explained Variance for 50 Components:",pca.explained_variance_ratio_[0:30].sum())
# Out:
# Explained Variance for 10 Components: 0.7833225643185457
# Explained Variance for 20 Components: 0.8419195112468112
# Explained Variance for 50 Components: 0.8665928408487957

# %% [markdown]
# #### PCA with 85% Explained Variance

# %%
pca = PCA(n_components=0.85)
X_pca = pca.fit_transform(X)

# %%
X_pca
# Out:
# array([[-5.29107617e-01, -9.60533607e-01,  9.16779276e-01, ...,
#         -2.28777490e-03, -3.01714792e-03, -5.89366140e-03],
#        [-5.41542443e-01, -9.96547379e-01,  8.24595101e-01, ...,
#         -3.70953225e-03, -6.61556620e-03, -7.00496317e-03],
#        [-5.46560483e-01, -9.61668019e-01,  9.57344276e-01, ...,
#         -4.22365042e-03, -7.87010458e-03, -5.29754446e-03],
#        ...,
#        [ 1.69810819e-01, -8.06459476e-01, -2.51489702e-01, ...,
#         -1.30051933e-02,  5.75103068e-04, -6.87919178e-03],
#        [ 1.93296664e-01, -8.03987528e-01, -1.19370280e-01, ...,
#         -4.82729044e-03, -1.65528488e-03, -8.64897807e-03],
#        [ 1.89098790e-01, -7.72416152e-01,  2.23390277e-03, ...,
#         -2.45080972e-02, -1.50829000e-02, -2.04059680e-02]])

# %%
print("Number of components with 85% explained variance:", len(pca.explained_variance_ratio_))
print("Number of PCA transformed features:", X_pca.shape[1])
# Out:
# Number of components with 85% explained variance: 23
# Number of PCA transformed features: 23

# %% [markdown]
# ### Train & Test Split

# %%
X_train_pca, X_test_pca, y_train_pca, y_test_pca = train_test_split(X_pca, y, test_size = 0.2, random_state = 666)

# %% [markdown]
# ## 3.2 Undersampled PCA Data

# %%
rUs = RandomUnderSampler(random_state=666)
X_ru, y_ru = rUs.fit_resample(X_train_pca, y_train_pca)
print('Sample classes undersampled :', dict(pd.Series(y_ru).value_counts()))
# Out:
# Sample classes undersampled : {0: 361454, 1: 361454}

# %% [markdown]
# ## 3.3 Model Training (PCA + Undersampled)

# %% [markdown]
# ### Decision Tree (PCA + Undersampled)

# %%
decision_tree_pca_ru = DecisionTreeClassifier(random_state=666)
decision_tree_pca_ru.fit(X_ru, y_ru)
# Out:
# DecisionTreeClassifier(random_state=666)

# %%
# Save the best model
joblib.dump(decision_tree_pca_ru, 'best_dt_pca_ru.pkl')

# To load the model later
#decision_tree_pca_ru = joblib.load('best_dt_pca_ru.pkl')
# Out:
# ['best_dt_pca_ru.pkl']

# %%
y_train_pred_dt_pca_ru = decision_tree_pca_ru.predict(X_ru)
y_test_pred_dt_pca_ru = decision_tree_pca_ru.predict(X_test_pca)
y_test_pred_prob_dt_pca_ru = decision_tree_pca_ru.predict_proba(X_test_pca)

# %% [markdown]
# ### Random Forest (PCA + Undersampled)

# %%
random_forest_pca_ru = RandomForestClassifier(random_state=666)
random_forest_pca_ru.fit(X_ru, y_ru)
# Out:
# RandomForestClassifier(random_state=666)

# %%
# Save the best model
joblib.dump(random_forest_pca_ru, 'best_rf_pca_ru.pkl')

# To load the model later
#random_forest_pca_ru = joblib.load('best_rf_pca_ru.pkl')
# Out:
# ['best_rf_pca_ru.pkl']

# %%
y_train_pred_rf_pca_ru = random_forest_pca_ru.predict(X_ru)
y_test_pred_rf_pca_ru = random_forest_pca_ru.predict(X_test_pca)
y_test_pred_prob_rf_pca_ru = random_forest_pca_ru.predict_proba(X_test_pca)

# %% [markdown]
# ## 3.4 Model Evaluation (PCA + Undersampled)

# %% [markdown]
# ### Decision Tree (PCA + Undersampled)

# %% [markdown]
# #### Evaluation Decision Tree (Training Data, PCA + Undersampled)

# %%
print("Decision Tree - Training Data (PCA + Undersampled)")
evaluate_model(y_ru, y_train_pred_dt_pca_ru)
# Out:
# Decision Tree - Training Data (PCA + Undersampled)
# Confusion Matrix:
#  [[361411     43]
#  [  1637 359817]]
# Accuracy: 0.9977
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       1.00      1.00      1.00    361454
#    Reached (<=6 min)       1.00      1.00      1.00    361454
#
#             accuracy                           1.00    722908
#            macro avg       1.00      1.00      1.00    722908
#         weighted avg       1.00      1.00      1.00    722908
#
# Balanced Accuracy: 0.9977
# (0.9976760528310656,
#  0.9976857317255141,
#  0.9976760528310656,
#  0.9976760415320935,
#  None,
#  0.9976760528310656)

# %% [markdown]
# #### Evaluation Decision Tree (Test Data, PCA + Undersampled)

# %%
print("\nDecision Tree - Test Data (PCA + Undersampled)")
dt_test_acc_pca_ru, dt_test_prec_pca_ru, dt_test_recall_pca_ru, dt_test_f1_pca_ru, dt_test_roc_pca_ru, dt_test_balacc_pca_ru = evaluate_model(y_test_pca, y_test_pred_dt_pca_ru, y_test_pred_prob_dt_pca_ru)
# Out:
# Decision Tree - Test Data (PCA + Undersampled)
# Confusion Matrix:
#  [[ 53205  37038]
#  [ 90053 127245]]
# Accuracy: 0.5868
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.37      0.59      0.46     90243
#    Reached (<=6 min)       0.77      0.59      0.67    217298
#
#             accuracy                           0.59    307541
#            macro avg       0.57      0.59      0.56    307541
#         weighted avg       0.66      0.59      0.60    307541
#
# ROC AUC Score: 0.5879
# Balanced Accuracy: 0.5876

# %% [markdown]
# ### Random Forest (PCA + Undersampled)

# %% [markdown]
# #### Evaluation Random Forest (Training Data, PCA + Undersampled)

# %%
print("\nRandom Forest - Training Data (PCA + Undersampled)")
evaluate_model(y_ru, y_train_pred_rf_pca_ru)
# Out:
# Random Forest - Training Data (PCA + Undersampled)
# Confusion Matrix:
#  [[360514    940]
#  [   744 360710]]
# Accuracy: 0.9977
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       1.00      1.00      1.00    361454
#    Reached (<=6 min)       1.00      1.00      1.00    361454
#
#             accuracy                           1.00    722908
#            macro avg       1.00      1.00      1.00    722908
#         weighted avg       1.00      1.00      1.00    722908
#
# Balanced Accuracy: 0.9977
# (0.9976705196235206,
#  0.997670665958488,
#  0.9976705196235206,
#  0.9976705194522806,
#  None,
#  0.9976705196235206)

# %%
print("\nRandom Forest - Test Data (PCA + Undersampled)")
rf_test_acc_pca_ru, rf_test_prec_pca_ru, rf_test_recall_pca_ru, rf_test_f1_pca_ru, rf_test_roc_pca_ru, rf_test_balacc_pca_ru = evaluate_model(y_test_pca, y_test_pred_rf_pca_ru, y_test_pred_prob_rf_pca_ru)
# Out:
# Random Forest - Test Data (PCA + Undersampled)
# Confusion Matrix:
#  [[ 57670  32573]
#  [ 70070 147228]]
# Accuracy: 0.6662
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.45      0.64      0.53     90243
#    Reached (<=6 min)       0.82      0.68      0.74    217298
#
#             accuracy                           0.67    307541
#            macro avg       0.64      0.66      0.64    307541
#         weighted avg       0.71      0.67      0.68    307541
#
# ROC AUC Score: 0.7162
# Balanced Accuracy: 0.6583

# %% [markdown]
# # 4. Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## 4.1 Model Training (Hyperparameter Tuning)

# %% [markdown]
# ### Decision Tree

# %%
param_grid_dt = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [10],
    'max_features': ['sqrt', 'log2'],
    'random_state': [666] 
}

grid_search_dt = GridSearchCV(
    estimator=DecisionTreeClassifier(),
    param_grid=param_grid_dt,
    scoring='accuracy',
    cv=5,
    n_jobs=-1
)

# %%
grid_search_dt.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'], 'max_depth': [10],
#                          'max_features': ['sqrt', 'log2'],
#                          'random_state': [666]},
#              scoring='accuracy')

# %%
# Save the best model
joblib.dump(grid_search_dt.best_estimator_, 'best_dt_hyp.pkl')

# To load the model later
#grid_search_dt = joblib.load('best_dt_hyp.pkl')

# %%
print(f'Best Parameters: {grid_search_dt.best_params_}')
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'random_state': 666}

# %%
y_train_pred_dt_hyp = grid_search_dt.predict(X_train)
y_test_pred_dt_hyp = grid_search_dt.predict(X_test)
y_test_pred_prob_dt_hyp = grid_search_dt.predict_proba(X_test)

# %% [markdown]
# ### Random Forest

# %%
param_grid_rf = {
    'n_estimators': [100],
    'criterion': ['gini', 'entropy'],
    'max_depth': [10],
    'max_features': ['sqrt'],
    'random_state': [666]
}

grid_search_rf_hyp = GridSearchCV(
    estimator=RandomForestClassifier(),
    param_grid=param_grid_rf,
    scoring='accuracy',
    cv=5,
    n_jobs=-1
)

# %%
grid_search_rf_hyp.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'], 'max_depth': [10],
#                          'max_features': ['sqrt'], 'n_estimators': [100],
#                          'random_state': [666]},
#              scoring='accuracy')

# %%
# Save the best model
#joblib.dump(grid_search_rf_hyp.best_estimator_, 'best_rf_hyp.pkl')

# To load the model later
grid_search_rf_hyp = joblib.load('best_rf_hyp.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 # Save the best model
#       2 #joblib.dump(grid_search_rf_hyp.best_estimator_, 'best_rf_hyp.pkl')
#       3
#       4 # To load the model later
# ----> 5 grid_search_rf_hyp = joblib.load('best_rf_hyp.pkl')
#
# NameError: name 'joblib' is not defined

# %%
y_train_pred_rf_hyp = grid_search_rf_hyp.predict(X_train)
y_test_pred_rf_hyp = grid_search_rf_hyp.predict(X_test)
y_test_pred_prob_rf_hyp = grid_search_rf_hyp.predict_proba(X_test)

# %% [markdown]
# ## 4.2 Model Evaluation (Hyperparameter Tuning)

# %% [markdown]
# ### Decision Tree

# %%
print("Decision Tree - Training Data (Hyperparameter)")
evaluate_model(y_train, y_train_pred_dt_hyp)
# Out:
# Decision Tree - Training Data (Hyperparameter)
# Confusion Matrix:
#  [[ 55539 305915]
#  [ 38074 830635]]
# Accuracy: 0.7204
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.59      0.15      0.24    361454
#    Reached (<=6 min)       0.73      0.96      0.83    868709
#
#             accuracy                           0.72   1230163
#            macro avg       0.66      0.55      0.54   1230163
#         weighted avg       0.69      0.72      0.66   1230163
#
# Balanced Accuracy: 0.5549
# (0.7203712028405992,
#  0.6620609633071782,
#  0.5549130757156897,
#  0.5362740514096647,
#  None,
#  0.5549130757156897)

# %%
print("\nDecision Tree - Test Data (Hyperparameter)")
dt_test_acc_hyp, dt_test_prec_hyp, dt_test_recall_hyp,dt_test_f1_hyp, dt_test_roc_hyp, dt_test_balacc_hyp = evaluate_model(y_test, y_test_pred_dt_hyp, y_test_pred_prob_dt_hyp)
# Out:
# Decision Tree - Test Data (Hyperparameter)
# Confusion Matrix:
#  [[ 13735  76508]
#  [  9832 207466]]
# Accuracy: 0.7193
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.58      0.15      0.24     90243
#    Reached (<=6 min)       0.73      0.95      0.83    217298
#
#             accuracy                           0.72    307541
#            macro avg       0.66      0.55      0.53    307541
#         weighted avg       0.69      0.72      0.66    307541
#
# ROC AUC Score: 0.6427
# Balanced Accuracy: 0.5535

# %% [markdown]
# ### Random Forest

# %%
print("\nRandom Forest - Training Data (Hyperparameter)")
evaluate_model(y_train, y_train_pred_rf_hyp)
# Out:
# Random Forest - Training Data (Hyperparameter)
# Confusion Matrix:
#  [[  8655 352799]
#  [   809 867900]]
# Accuracy: 0.7126
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.91      0.02      0.05    361454
#    Reached (<=6 min)       0.71      1.00      0.83    868709
#
#             accuracy                           0.71   1230163
#            macro avg       0.81      0.51      0.44   1230163
#         weighted avg       0.77      0.71      0.60   1230163
#
# Balanced Accuracy: 0.5115
# (0.7125519138520667,
#  0.8127521283488645,
#  0.5115068443396588,
#  0.4387148143515099,
#  None,
#  0.5115068443396588)

# %%
print("\nRandom Forest - Test Data (Hyperparameter)")
rf_test_acc_hyp, rf_test_prec_hyp, rf_test_recall_hyp, rf_test_f1_hyp, rf_test_roc_hyp, rf_test_balacc_hyp = evaluate_model(y_test, y_test_pred_rf_hyp, y_test_pred_prob_rf_hyp)
# Out:
# Random Forest - Test Data (Hyperparameter)
# Confusion Matrix:
#  [[  2059  88184]
#  [   297 217001]]
# Accuracy: 0.7123
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.87      0.02      0.04     90243
#    Reached (<=6 min)       0.71      1.00      0.83    217298
#
#             accuracy                           0.71    307541
#            macro avg       0.79      0.51      0.44    307541
#         weighted avg       0.76      0.71      0.60    307541
#
# ROC AUC Score: 0.7208
# Balanced Accuracy: 0.5107

# %% [markdown]
# # 5. Undersampled + Hyperparameter Tuning

# %% [markdown]
# ## 5.1 Model Training (Undersampled + Hyperparameter Tuning)

# %% [markdown]
# ### Decision Tree

# %%
param_grid_dt = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [10],
    'random_state': [666] 
}

grid_search_dt_hyp_ru = GridSearchCV(
    estimator=DecisionTreeClassifier(),
    param_grid=param_grid_dt,
    scoring='accuracy',
    cv=5,
    n_jobs=-1
)

# %%
grid_search_dt_hyp_ru.fit(X_undsam, y_undsam)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'], 'max_depth': [10],
#                          'random_state': [666]},
#              scoring='accuracy')

# %%
print(f'Best Parameters: {grid_search_dt_hyp_ru.best_params_}')
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': 10, 'random_state': 666}

# %%
# Save the best model
joblib.dump(grid_search_dt_hyp_ru.best_estimator_, 'best_dt_hyp_ru.pkl')

# To load the model later
#grid_search_dt_hyp_ru = joblib.load('best_dt_hyp_ru.pkl')
# Out:
# ['best_dt_hyp_ru.pkl']

# %%
y_train_pred_dt_hyp_ru = grid_search_dt_hyp_ru.predict(X_undsam)
y_test_pred_dt_hyp_ru = grid_search_dt_hyp_ru.predict(X_test)
y_test_pred_prob_dt_hyp_ru = grid_search_dt_hyp_ru.predict_proba(X_test)

# %% [markdown]
# ### Random Forest

# %%
param_grid_rf = {
    'n_estimators': [200],
    'criterion': ['gini', 'entropy'],
    'max_depth': [10],
    'random_state': [666]
}

grid_search_rf_hyp_ru = GridSearchCV(
    estimator=RandomForestClassifier(),
    param_grid=param_grid_rf,
    scoring='accuracy',
    cv=5,
    n_jobs=-1
)

# %%
grid_search_rf_hyp_ru.fit(X_undsam, y_undsam)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'], 'max_depth': [10],
#                          'n_estimators': [200], 'random_state': [666]},
#              scoring='accuracy')

# %%
# Save the best model
#joblib.dump(grid_search_rf_hyp_ru.best_estimator_, 'best_rf_hyp_ru.pkl')

# To load the model later
grid_search_rf_hyp_ru = joblib.load('best_rf_hyp_ru.pkl')

# %%
y_train_pred_rf_hyp_ru = grid_search_rf_hyp_ru.predict(X_undsam)
y_test_pred_rf_hyp_ru = grid_search_rf_hyp_ru.predict(X_test)
y_test_pred_prob_rf_hyp_ru = grid_search_rf_hyp_ru.predict_proba(X_test)

# %% [markdown]
# ## 5.2 Model Evaluation (Undersampled + Hyperparameter Tuning)

# %% [markdown]
# ### Decision Tree

# %%
print("Decision Tree - Training Data (Undersampled + Hyperparameter)")
evaluate_model(y_undsam, y_train_pred_dt_hyp_ru)
# Out:
# Decision Tree - Training Data (Undersampled + Hyperparameter)
# Confusion Matrix:
#  [[219630 141824]
#  [ 91689 269765]]
# Accuracy: 0.6770
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.71      0.61      0.65    361454
#    Reached (<=6 min)       0.66      0.75      0.70    361454
#
#             accuracy                           0.68    722908
#            macro avg       0.68      0.68      0.68    722908
#         weighted avg       0.68      0.68      0.68    722908
#
# Balanced Accuracy: 0.6770
# (0.6769810266313279,
#  0.6804527040323269,
#  0.6769810266313279,
#  0.6754199009603485,
#  None,
#  0.6769810266313279)

# %%
print("\nDecision Tree - Test Data (Undersampled + Hyperparameter)")
dt_test_acc_hyp_ru, dt_test_prec_hyp_ru, dt_test_recall_hyp_ru,dt_test_f1_hyp_ru, dt_test_roc_hyp_ru, dt_test_balacc_hyp_ru = evaluate_model(y_test, y_test_pred_dt_hyp_ru, y_test_pred_prob_dt_hyp_ru)
# Out:
# Decision Tree - Test Data (Undersampled + Hyperparameter)
# Confusion Matrix:
#  [[ 54359  35884]
#  [ 56019 161279]]
# Accuracy: 0.7012
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.49      0.60      0.54     90243
#    Reached (<=6 min)       0.82      0.74      0.78    217298
#
#             accuracy                           0.70    307541
#            macro avg       0.66      0.67      0.66    307541
#         weighted avg       0.72      0.70      0.71    307541
#
# ROC AUC Score: 0.7312
# Balanced Accuracy: 0.6723

# %% [markdown]
# ### Random Forest

# %%
print("\nRandom Forest - Training Data (Undersampled + Hyperparameter)")
evaluate_model(y_undsam, y_train_pred_rf_hyp_ru)
# Out:
# Random Forest - Training Data (Undersampled + Hyperparameter)
# Confusion Matrix:
#  [[194075 167379]
#  [ 75979 285475]]
# Accuracy: 0.6634
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.72      0.54      0.61    361454
#    Reached (<=6 min)       0.63      0.79      0.70    361454
#
#             accuracy                           0.66    722908
#            macro avg       0.67      0.66      0.66    722908
#         weighted avg       0.67      0.66      0.66    722908
#
# Balanced Accuracy: 0.6634
# (0.6633624195609953,
#  0.6745216880331828,
#  0.6633624195609953,
#  0.6578936776234506,
#  None,
#  0.6633624195609953)

# %%
print("\nRandom Forest - Test Data (Undersampled + Hyperparameter)")
rf_test_acc_hyp_ru, rf_test_prec_hyp_ru, rf_test_recall_hyp_ru, rf_test_f1_hyp_ru, rf_test_roc_hyp_ru, rf_test_balacc_hyp_ru = evaluate_model(y_test, y_test_pred_rf_hyp_ru, y_test_pred_prob_rf_hyp_ru)
# Out:
# Random Forest - Test Data (Undersampled + Hyperparameter)
# Confusion Matrix:
#  [[ 48317  41926]
#  [ 45793 171505]]
# Accuracy: 0.7148
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.51      0.54      0.52     90243
#    Reached (<=6 min)       0.80      0.79      0.80    217298
#
#             accuracy                           0.71    307541
#            macro avg       0.66      0.66      0.66    307541
#         weighted avg       0.72      0.71      0.72    307541
#
# ROC AUC Score: 0.7239
# Balanced Accuracy: 0.6623

# %% [markdown]
# # 6. PCA + Undersampled + Hyperparameter Tuning

# %% [markdown]
# ## 6.1 Model Training (PCA + Undersampled + Hyperparameter Tuning)

# %% [markdown]
# ### Decision Tree

# %%
param_grid_dt = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [10],
    'random_state': [666] 
}

grid_search_dt_hyp_ru_pca = GridSearchCV(
    estimator=DecisionTreeClassifier(),
    param_grid=param_grid_dt,
    scoring='accuracy',
    cv=5,
    n_jobs=-1
)

# %%
grid_search_dt_hyp_ru_pca.fit(X_ru, y_ru)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'], 'max_depth': [10],
#                          'random_state': [666]},
#              scoring='accuracy')

# %%
print(f'Best Parameters: {grid_search_dt_hyp_ru_pca.best_params_}')
# Out:
# Best Parameters: {'criterion': 'entropy', 'max_depth': 10, 'random_state': 666}

# %%
# Save the best model
joblib.dump(grid_search_dt_hyp_ru_pca.best_estimator_, 'best_dt_hyp_ru_pca.pkl')

# To load the model later
#grid_search_dt_hyp_ru_pca = joblib.load('best_dt_hyp_ru_pca.pkl')
# Out:
# ['best_dt_hyp_ru_pca.pkl']

# %%
y_train_pred_dt_hyp_ru_pca = grid_search_dt_hyp_ru_pca.predict(X_ru)
y_test_pred_dt_hyp_ru_pca = grid_search_dt_hyp_ru_pca.predict(X_test_pca)
y_test_pred_prob_dt_hyp_ru_pca = grid_search_dt_hyp_ru_pca.predict_proba(X_test_pca)

# %% [markdown]
# ### Random Forest

# %%
param_grid_rf = {
    'n_estimators': [200],
    'criterion': ['gini', 'entropy'],
    'max_depth': [10],
    'random_state': [666]
}

grid_search_rf_hyp_ru_pca = GridSearchCV(
    estimator=RandomForestClassifier(),
    param_grid=param_grid_rf,
    scoring='accuracy',
    cv=5,
    n_jobs=-1
)

# %%
grid_search_rf_hyp_ru_pca.fit(X_ru, y_ru)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'], 'max_depth': [10],
#                          'n_estimators': [200], 'random_state': [666]},
#              scoring='accuracy')

# %%
# Save the best model
joblib.dump(grid_search_rf_hyp_ru_pca.best_estimator_, 'best_rf_hyp_ru_pca.pkl')

# To load the model later
#grid_search_rf_hyp_ru_pca = joblib.load('best_rf_hyp_ru_pca.pkl')
# Out:
# ['best_rf_hyp_ru_pca.pkl']

# %%
y_train_pred_rf_hyp_ru_pca = grid_search_rf_hyp_ru_pca.predict(X_ru)
y_test_pred_rf_hyp_ru_pca = grid_search_rf_hyp_ru_pca.predict(X_test_pca)
y_test_pred_prob_rf_hyp_ru_pca = grid_search_rf_hyp_ru_pca.predict_proba(X_test_pca)

# %% [markdown]
# ## 6.2 Model Evaluation (PCA + Undersampled + Hyperparameter Tuning)

# %% [markdown]
# ### Decision Tree

# %%
print("Decision Tree - Training Data (Undersampled + Hyperparameter + PCA)")
evaluate_model(y_ru, y_train_pred_dt_hyp_ru_pca)
# Out:
# Decision Tree - Training Data (Undersampled + Hyperparameter + PCA)
# Confusion Matrix:
#  [[219132 142322]
#  [ 92150 269304]]
# Accuracy: 0.6757
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.70      0.61      0.65    361454
#    Reached (<=6 min)       0.65      0.75      0.70    361454
#
#             accuracy                           0.68    722908
#            macro avg       0.68      0.68      0.67    722908
#         weighted avg       0.68      0.68      0.67    722908
#
# Balanced Accuracy: 0.6757
# (0.6756544401223945,
#  0.6791052827362619,
#  0.6756544401223945,
#  0.6740845773974498,
#  None,
#  0.6756544401223945)

# %%
print("\nDecision Tree - Test Data (Undersampled + Hyperparameter + PCA)")
dt_test_acc_hyp_ru_pca, dt_test_prec_hyp_ru_pca, dt_test_recall_hyp_ru_pca,dt_test_f1_hyp_ru_pca, dt_test_roc_hyp_ru_pca, dt_test_balacc_hyp_ru_pca = evaluate_model(y_test_pca, y_test_pred_dt_hyp_ru_pca, y_test_pred_prob_dt_hyp_ru_pca)
# Out:
# Decision Tree - Test Data (Undersampled + Hyperparameter + PCA)
# Confusion Matrix:
#  [[ 54035  36208]
#  [ 56949 160349]]
# Accuracy: 0.6971
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.49      0.60      0.54     90243
#    Reached (<=6 min)       0.82      0.74      0.77    217298
#
#             accuracy                           0.70    307541
#            macro avg       0.65      0.67      0.66    307541
#         weighted avg       0.72      0.70      0.71    307541
#
# ROC AUC Score: 0.7276
# Balanced Accuracy: 0.6683

# %% [markdown]
# ### Random Forest

# %%
print("\nRandom Forest - Training Data (Undersampled + Hyperparameter)")
evaluate_model(y_ru, y_train_pred_rf_hyp_ru_pca)
# Out:
# Random Forest - Training Data (Undersampled + Hyperparameter)
# Confusion Matrix:
#  [[224611 136843]
#  [ 93487 267967]]
# Accuracy: 0.6814
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.71      0.62      0.66    361454
#    Reached (<=6 min)       0.66      0.74      0.70    361454
#
#             accuracy                           0.68    722908
#            macro avg       0.68      0.68      0.68    722908
#         weighted avg       0.68      0.68      0.68    722908
#
# Balanced Accuracy: 0.6814
# (0.6813840765353267,
#  0.6840318779059131,
#  0.6813840765353267,
#  0.6802338992815493,
#  None,
#  0.6813840765353267)

# %%
print("\nRandom Forest - Test Data (Undersampled + Hyperparameter + PCA)")
rf_test_acc_hyp_ru_pca, rf_test_prec_hyp_ru_pca, rf_test_recall_hyp_ru_pca, rf_test_f1_hyp_ru_pca, rf_test_roc_hyp_ru_pca, rf_test_balacc_hyp_ru_pca = evaluate_model(y_test_pca, y_test_pred_rf_hyp_ru_pca, y_test_pred_prob_rf_hyp_ru_pca)
# Out:
# Random Forest - Test Data (Undersampled + Hyperparameter + PCA)
# Confusion Matrix:
#  [[ 55218  35025]
#  [ 57654 159644]]
# Accuracy: 0.6986
# Classification Report:
#                        precision    recall  f1-score   support
#
# Not Reached (>6 min)       0.49      0.61      0.54     90243
#    Reached (<=6 min)       0.82      0.73      0.78    217298
#
#             accuracy                           0.70    307541
#            macro avg       0.65      0.67      0.66    307541
#         weighted avg       0.72      0.70      0.71    307541
#
# ROC AUC Score: 0.7352
# Balanced Accuracy: 0.6733

# %% [markdown]
# # 7. Comparison of Different Models

# %% [markdown]
# ## 7.1 Evaluation Metrics Comparison

# %%
model_eval = {
    'Model': [
        'Decision Tree (B)', 'Decision Tree (U)', 'Decision Tree (PCA+U)',
        'Decision Tree (Hyp)', 'Decision Tree (U+Hyp)', 'Decision Tree (PCA+U+Hyp)',
        'Random Forest (B)', 'Random Forest (U)', 'Random Forest (PCA+U)',
        'Random Forest (Hyp)', 'Random Forest (U+Hyp)', 'Random Forest (PCA+U+Hyp)'
    ],
    'Accuracy': [dt_test_acc, dt_test_acc_ru, dt_test_acc_pca_ru,
                 dt_test_acc_hyp, dt_test_acc_hyp_ru, dt_test_acc_hyp_ru_pca,
                 rf_test_acc, rf_test_acc_ru, rf_test_acc_pca_ru,
                 rf_test_acc_hyp, rf_test_acc_hyp_ru, rf_test_acc_hyp_ru_pca
                ],
    'Precision': [dt_test_prec, dt_test_prec_ru, dt_test_prec_pca_ru,
                  dt_test_prec_hyp, dt_test_prec_hyp_ru, dt_test_prec_hyp_ru_pca,
                  rf_test_prec, rf_test_prec_ru, rf_test_prec_pca_ru,
                  rf_test_prec_hyp, rf_test_prec_hyp_ru, rf_test_prec_hyp_ru_pca
                 ],
    'Recall': [dt_test_recall, dt_test_recall_ru, dt_test_recall_pca_ru,
               dt_test_recall_hyp, dt_test_recall_hyp_ru, dt_test_recall_hyp_ru_pca,
               rf_test_recall, rf_test_recall_ru, rf_test_recall_pca_ru,
               rf_test_recall_hyp, rf_test_recall_hyp_ru, rf_test_recall_hyp_ru_pca
              ],
    'F1 Score': [dt_test_f1, dt_test_f1_ru, dt_test_f1_pca_ru,
                 dt_test_f1_hyp, dt_test_f1_hyp, dt_test_f1_hyp_ru_pca,
                 rf_test_f1, rf_test_f1_ru, rf_test_f1_pca_ru,
                 rf_test_f1_hyp, rf_test_f1_hyp, rf_test_f1_hyp_ru_pca
                ],
    'ROC AUC Score': [dt_test_roc, dt_test_roc_ru, dt_test_roc_pca_ru,
                      dt_test_roc_hyp, dt_test_roc_hyp_ru, dt_test_roc_hyp_ru_pca,
                      rf_test_roc, rf_test_roc_ru, rf_test_roc_pca_ru,
                      rf_test_roc_hyp, rf_test_roc_hyp_ru, rf_test_roc_hyp_ru_pca,
                     ],
    'Balanced Accuracy': [dt_test_balacc, dt_test_balacc_ru, dt_test_balacc_pca_ru,
                          dt_test_balacc_hyp, dt_test_balacc_hyp_ru, dt_test_balacc_hyp_ru_pca,
                          rf_test_balacc, rf_test_balacc_ru, rf_test_balacc_pca_ru,
                          rf_test_balacc_hyp, rf_test_balacc_hyp_ru, rf_test_balacc_hyp_ru_pca,
                         ]
}

clf_test_eval = pd.DataFrame(model_eval)
clf_test_eval
# Out:
#                         Model  Accuracy  Precision    Recall  F1 Score  \
# 0           Decision Tree (B)  0.673000   0.604131  0.602984  0.603532
# 1           Decision Tree (U)  0.611450   0.592154  0.610060  0.584337
# 2       Decision Tree (PCA+U)  0.586751   0.572970  0.587577  0.561326
# 3         Decision Tree (Hyp)  0.719257   0.656694  0.553477  0.534563
# 4       Decision Tree (U+Hyp)  0.701168   0.655239  0.672282  0.534563
# 5   Decision Tree (PCA+U+Hyp)  0.697091   0.651330  0.668347  0.655980
# 6           Random Forest (B)  0.743114   0.686924  0.638449  0.649350
# 7           Random Forest (U)  0.673504   0.642369  0.666658  0.643073
# 8       Random Forest (PCA+U)  0.666246   0.635151  0.658296  0.635321
# 9         Random Forest (Hyp)  0.712295   0.792493  0.510725  0.437562
# 10      Random Forest (U+Hyp)  0.714773   0.658486  0.662336  0.437562
# 11  Random Forest (PCA+U+Hyp)  0.698645   0.654644  0.673279  0.659372
#
#     ROC AUC Score  Balanced Accuracy
# 0        0.603363           0.602984
# 1        0.610380           0.610060
# 2        0.587882           0.587577
# 3        0.642705           0.553477
# 4        0.731228           0.672282
# 5        0.727622           0.668347
# 6        0.724175           0.638449
# 7        0.727693           0.666658
# 8        0.716168           0.658296
# 9        0.720772           0.510725
# 10       0.723892           0.662336
# 11       0.735163           0.673279

# %%
clf_test_eval.sort_values(by="Balanced Accuracy", ascending = False)
# Out:
#                         Model  Accuracy  Precision    Recall  F1 Score  \
# 11  Random Forest (PCA+U+Hyp)  0.698645   0.654644  0.673279  0.659372
# 4       Decision Tree (U+Hyp)  0.701168   0.655239  0.672282  0.534563
# 5   Decision Tree (PCA+U+Hyp)  0.697091   0.651330  0.668347  0.655980
# 7           Random Forest (U)  0.673504   0.642369  0.666658  0.643073
# 10      Random Forest (U+Hyp)  0.714773   0.658486  0.662336  0.437562
# 8       Random Forest (PCA+U)  0.666246   0.635151  0.658296  0.635321
# 6           Random Forest (B)  0.743114   0.686924  0.638449  0.649350
# 1           Decision Tree (U)  0.611450   0.592154  0.610060  0.584337
# 0           Decision Tree (B)  0.673000   0.604131  0.602984  0.603532
# 2       Decision Tree (PCA+U)  0.586751   0.572970  0.587577  0.561326
# 3         Decision Tree (Hyp)  0.719257   0.656694  0.553477  0.534563
# 9         Random Forest (Hyp)  0.712295   0.792493  0.510725  0.437562
#
#     ROC AUC Score  Balanced Accuracy
# 11       0.735163           0.673279
# 4        0.731228           0.672282
# 5        0.727622           0.668347
# 7        0.727693           0.666658
# 10       0.723892           0.662336
# 8        0.716168           0.658296
# 6        0.724175           0.638449
# 1        0.610380           0.610060
# 0        0.603363           0.602984
# 2        0.587882           0.587577
# 3        0.642705           0.553477
# 9        0.720772           0.510725

# %%
df_melted = clf_test_eval.melt(id_vars='Model', var_name='Metric', value_name='Score')

sns.set_palette('Set2')

plt.figure(figsize=(14, 8))
sns.barplot(data=df_melted, x='Metric', y='Score', hue='Model')

plt.title('Comparison of Model Test Performance')
plt.xlabel('')
plt.ylabel('Test Score')
plt.legend(loc='lower center', prop={'size': 8}) 

plt.tight_layout()
plt.savefig("/Users/bennyschellinger/Desktop/DataScience/MLE_DataScientest/04_Projekt/MAY24_BDS_INT_Fire_Brigade/img/comp_test_perf_clf_models.png")
plt.show()

# %% [markdown]
# ## 7.2 Receiver Operating Characteristic Curve

# %%
from sklearn.metrics import roc_curve, auc

model_probas = {
    'Decision Tree (B)': y_test_pred_prob_dt,
    'Decision Tree (U)': y_test_pred_prob_dt_undsam,
    'Decision Tree (PCA+U)': y_test_pred_prob_dt_pca_ru,
    'Decision Tree (Hyp)': y_test_pred_prob_dt_hyp,
    'Decision Tree (U+Hyp)': y_test_pred_prob_dt_hyp_ru,
    'Decision Tree (PCA+U+Hyp)': y_test_pred_prob_dt_hyp_ru_pca,
    
    'Random Forest (B)': y_test_pred_prob_rf,
    'Random Forest (U)': y_test_pred_prob_rf_undsam,
    'Random Forest (PCA+U)': y_test_pred_prob_rf_pca_ru,
    'Random Forest (Hyp)': y_test_pred_prob_rf_hyp,
    'Random Forest (U+Hyp)': y_test_pred_prob_rf_hyp_ru,
    'Random Forest (PCA+U+Hyp)': y_test_pred_prob_rf_hyp_ru_pca
}

true_labels = {
    'Decision Tree (B)': y_test,
    'Decision Tree (U)': y_test,
    'Decision Tree (PCA+U)': y_test_pca,
    'Decision Tree (Hyp)': y_test,
    'Decision Tree (U+Hyp)': y_test,
    'Decision Tree (PCA+U+Hyp)': y_test_pca, 
    'Random Forest (B)': y_test,
    'Random Forest (U)': y_test,
    'Random Forest (PCA+U)': y_test_pca,
    'Random Forest (Hyp)': y_test,
    'Random Forest (U+Hyp)': y_test,
    'Random Forest (PCA+U+Hyp)': y_test_pca
}

def plot_roc_auc_multiple_models(true_labels, model_probas):
    plt.figure(figsize=(10, 8))
    
    for model_name, y_proba in model_probas.items():
        y_true = true_labels[model_name]
        fpr, tpr, _ = roc_curve(y_true, y_proba[:, 1])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, label=f'{model_name} (AUC = {roc_auc:.2f})')
    
    # Plot the random line
    plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--', label='Random (AUC = 0.5)')
    
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic - Multiple Models')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.savefig("/Users/bennyschellinger/Desktop/DataScience/MLE_DataScientest/04_Projekt/MAY24_BDS_INT_Fire_Brigade/img/roc_test_perf_clf_models.png")
    plt.show()

plot_roc_auc_multiple_models(true_labels, model_probas)

# %% [markdown]
# # 8. Best Model & Parameter

# %% [markdown]
# #### Best Model:
# -> Random Forest (Balanced + PCA + Hyperparameter Tuning)

# %% [markdown]
# ### Best Parameter for RF

# %%
print(f'Best Parameters: {grid_search_rf_hyp_ru_pca.best_params_}')
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 200, 'random_state': 666}

# %%
best_model = grid_search_rf_hyp_ru_pca.best_estimator_
y_p = best_model.predict(X_test_pca)
balanced_acc = balanced_accuracy_score(y_test_pca, y_p)
print(f'Balanced Accuracy on Test Data: {balanced_acc:.4f}')
# Out:
# Balanced Accuracy on Test Data: 0.6733
